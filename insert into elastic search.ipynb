# %% [markdown]
# # Read file from json and save only kewords

# %%
import json

keywords = [  'pen','water', 'coffee', 'ham','tea','bread'
           'milk','apple', 'cranberry','straberry','banana','blueberry','blackberry','mango','oil','salt',
          'pepper','sugar','baking sheet','tin roll','foil','syrup','honey','flower','flour','paper','pan','lemon','corn','cucumber','potato','carrot','cauliflower','broccoli', 'beans',
          'mushroom','rice', 'pasta','lettuce','salary', 'asparagus', 'onion','cabbage','dressing','egg','butter','cheese','juice']

id_ = 1
with open('/Users/yumengluo/Desktop/claire/Columbia/6998/6998-team/cc6998-grp-prj/data/items_summary.json', 'w') as file:
    for keyword in keywords:

        with open('/Users/yumengluo/Desktop/claire/Columbia/6998/6998-team/'+keyword+'.json', 'r') as file1:
            merchandise_list = json.load(file1)
            
        for i in range(len(merchandise_list)):
            m = merchandise_list[i]
            ids = { "index" : { "_index": "product-search", "_id" : str(id_) } }
            json.dump(ids, file)
            file.write("\n")
            item = []
            item.append(m['title'])
            item.append(m['keyword'])
            item += m['description']
            #print(item)
            info = {"merchandise_id": m['id'], "search_text": item}
            json.dump(info, file)
            file.write("\n")
            id_+=1
            
file.close()
f = '/Users/yumengluo/Desktop/claire/Columbia/6998/6998-team/cc6998-grp-prj/data/items_summary.json'
# !curl -XPOST -u 'claireluo:Abcd1234.' 'https://search-item-search-dqlmodc2m5iid3hfibwvx3egkq.us-east-1.es.amazonaws.com/_bulk' --data-binary @$f -H 'Content-Type: application/json'
# Out:
# {"took":265,"errors":false,"items":[{"index":{"_index":"product-search","_type":"_doc","_id":"1","_version":87,"result":"updated","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":506,"_primary_term":1,"status":200}},{"index":{"_index":"product-search","_type":"_doc","_id":"2","_version":87,"result":"updated","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":342,"_primary_term":1,"status":200}},{"index":{"_index":"product-search","_type":"_doc","_id":"3","_version":87,"result":"updated","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":676,"_primary_term":1,"status":200}},{"index":{"_index":"product-search","_type":"_doc","_id":"4","_version":87,"result":"updated","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":86,"_primary_term":1,"status":200}},{"index":{"_index":"product-search","_type":"_doc","_id":"5","_version":87,"result":"updated","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":677,"_primary_term":1,"status":200}},{"index":{"_index":"product-search","_type":"_doc","_id":"6","_version":87,"result":"updated","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":343,"_primary_term":1,"status":200}},{"index":{"_index":"product-search","_type":"_doc","_id":"7","_version":85,"result":"updated","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":420,"_primary_term":1,"status":200}},{"index":{"_index":"product-search","_type":"_doc","_id":"8","_version":85,"result":"updated","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":421,"_primary_term":1,"status":200}},{"index":{"_index":"product-search","_type":"_doc","_id":"9","_version":85,"result":"updated","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":678,"_primary_term":1,"status":200}},{"index":{"_index":"product-search","_type":"_doc","_id":"10","_version":85,"result":"updated","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":422,"_primary_term":1,"status":200}},{"index":{"_index":"product-search","_type":"_doc","_id":"11","_version":85,"result":"updated","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":679,"_primary_term":1,"status":200}},{"index":{"_index":"product-search","_type":"_doc","_id":"12","_version":85,"result":"updated","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":507,"_primary_term":1,"status":200}},{"index":{"_index":"product-search","_type":"_doc","_id":"13","_version":85,"result":"updated","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":680,"_primary_term":1,"status":200}},{"index":{"_index":"product-search","_type":"_doc","_id":"14","_version":85,"result":"updated","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":423,"_primary_term":1,"status":200}},{"index":{"_index":"product-search","_type":"_doc","_id":"15","_version":85,"result":"updated","_shards":{"total":2,"successful":1,"failed":0},"_seq_no
#         "_score" : 6.0303955,
#         "_source" : {
#           "merchandise_id" : "54407091",
#           "search_text" : [
#             "Purified Drinking Water - 24pk/8 fl oz Bottles - Good & Gather&#8482;",
#             "water",
#             "Pack includes 24 plastic water bottles with resealable lids",
#             "8oz bottles are perfect for carrying with you wherever you go",
#             "Recyclable for easy disposal",
#             "Purified through reverse-osmosis and advanced-filtration technologies"
#           ]
#         }
#       },
#       {
#         "_index" : "product-search",
#         "_type" : "_doc",
#         "_id" : "45",
#         "_score" : 6.0303955,
#         "_source" : {
#           "merchandise_id" : "13097687",
#           "search_text" : [
#             "Deer Park Brand 100% Natural Spring Water - 24pk/16.9 fl oz Bottles",
#             "water",
#             "• 16.9-ounce/.5-Liter plastic bottle: easy to take along in a purse or backpack",
#             "• Popular 24-Pack: stock up with enough water to satisfy the entire family",
#             "• 100% natural spring water: zero calories, no sweeteners and no artificial colors or flavors",
#             "• Contains naturally balanced minerals for a crisp, clean taste",
#             "• Every bottle is 100% recyclable (excluding label and cap)",
#             "• Water source information may vary depending on bottling facility location. Applicable bottle deposits and/or sales tax may apply."
#           ]
#         }
#       },
#       {
#         "_index" : "product-search",
#         "_type" : "_doc",
#         "_id" : "35",
#         "_score" : 5.7340384,
#         "_source" : {
#           "merchandise_id" : "13097504",
#           "search_text" : [
#             "Arrowhead Brand 100% Mountain Spring Water - 24pk/16.9 fl oz Bottles",
#             "water",
#             "• 16.9-ounce/.5-Liter plastic bottle: easy to take along in a purse or backpack",
#             "• Popular 24-Pack: stock up with enough water to satisfy the entire family",
#             "• 100% mountain spring water: zero calories, no sweeteners and no artificial colors or flavors",
#             "• Contains a perfectly balanced natural mineral composition for a crisp, refreshing taste",
#             "• Every bottle is 100% recyclable (excluding label and cap)",
#             "• Water source information may vary depending on bottling facility location. Applicable bottle deposits and/or sales tax may apply."
#           ]
#         }
#       },
#       {
#         "_index" : "product-search",
#         "_type" : "_doc",
#         "_id" : "36",
#         "_score" : 5.7340384,
#         "_source" : {
#           "merchandise_id" : "13097688",
#           "search_text" : [
#             "Ice Mountain Brand 100% Natural Spring Water - 24pk/16.9 fl oz Bottles",
#             "water",
#             "• 16.9-ounce/.5-Liter plastic bottle: easy to take along in a purse or backpack",
#             "• Popular 24-Pack: stock up with enough water to satisfy the entire family",
#             "• 100% natural spring water: zero calories, no sweeteners and no artificial colors or flavors",
#             "• Contains naturally balanced minerals for a crisp, clean taste",
#             "• Every bottle is 100% recyclable (excluding label and cap)",
#             "• Water source information may vary depending on bottling facility location. Applicable bottle deposits and/or sales tax may apply."
#           ]
#         }
#       },
#       {
#         "_index" : "product-search",
#         "_type" : "_doc",
#         "_id" : "37",
#         "_score" : 5.7340384,
#         "_source" : {
#           "merchandise_id" : "47108322",
#           "search_text" : [
#             "Zephyrhills Brand 100% Natural Spring Water - 24pk/16.9 fl oz Bottles",
#             "water",
#             "• 16.9-ounce/.5-Liter plastic bottle: easy to take along in a purse or backpack",
#             "• Popular 24-Pack: stock up with enough water to satisfy the entire family",
#             "• 100% natural spring water: zero calories, no sweeteners and no artificial colors or flavors",
#             "• Contains naturally balanced minerals for a crisp, clean taste",
#             "• Every bottle is 100% recyclable (excluding label and cap)",
#             "• Water source information may vary depending on bottling facility location. Applicable bottle deposits and/or sales tax may apply."
#           ]
#         }
#       },
#       {
#         "_index" : "product-search",
#         "_type" : "_doc",
#         "_id" : "41",
#         "_score" : 5.7340384,
#         "_source" : {
#           "merchandise_id" : "14150940",
#           "search_text" : [
#             "Poland Spring Brand 100% Natural Spring Water - 101.4 fl oz Jug",
#             "water",
#             "• 101.4-ounce/3-Liter plastic jug with handle: easy to pour for all your kitchen needs",
#             "• Perfect when more water is needed, instead of bringing multiple small bottles",
#             "• 100% natural spring water: zero calories, no sweeteners and no artificial colors or flavors",
#             "• Contains naturally balanced minerals for a crisp, clean taste",
#             "• Every bottle is 100% recyclable (excluding label and cap)",
#             "• Water source information may vary depending on bottling facility location. Applicable bottle deposits and/or sales tax may apply."
#           ]
#         }
#       },
#       {
#         "_index" : "product-search",
#         "_type" : "_doc",
#         "_id" : "42",
#         "_score" : 5.7340384,
#         "_source" : {
#           "merchandise_id" : "14746217",
#           "search_text" : [
#             "FIJI Natural Artesian Water - 6pk/16.9 fl oz Bottles",
#             "water",
#             "PACK SIZE: Pack of 6, 500mL (16.9oz) bottles",
#             "EVERYDAY HYDRATION: Perfect for quenching thirst on the go, in the office, and at events",
#             "NATURAL ELECTROLYTES: As tropical rain filters through volcanic rock, it gathers electrolytes naturally, giving FIJI Water significantly more electrolytes than other brands",
#             "NATURAL ARTESIAN: Bottled from a natural artesian aquifer in the remote Fiji Islands ·SOFT, SMOOTH TASTE: As it filters through ancient rock, water naturally acquires that silica that gives FIJI its signature soft, smooth taste"
#           ]
#         }
#       },
#       {
#         "_index" : "product-search",
#         "_type" : "_doc",
#         "_id" : "26",
#         "_score" : 5.6917257,
#         "_source" : {
#           "merchandise_id" : "54444789",
#           "search_text" : [
#             "Purified Water - 1gal - Good & Gather&#8482;",
#             "water",
#             "1gal water jug is perfect for a wide variety of events",
#             "Handle makes for easy carrying and pouring",
#             "Resealable lid helps prevent spills",
#             "Purified through reverse-osmosis and advanced-filtration technologies"
#           ]
#         }
#       },
#       {
#         "_index" : "product-search",
#         "_type" : "_doc",
#         "_id" : "28",
#         "_score" : 5.6917257,
#         "_source" : {
#           "merchandise_id" : "14978383",
#           "search_text" : [
#             "Dasani Purified Water - 24pk/16.9 fl oz Bottles",
#             "water",
#             "Designed to be a great tasting water, DASANI is filtered by reverse osmosis to remove impurities, then enhanced with a special blend of minerals for the pure, crisp, fresh taste that's delightfully DASANI.",
#             "Purified water enhanced with minerals for a pure, fresh taste.",
#             "PlantBottle packaging is up to 30% made from plants",
#             "100% recyclable plastic bottle"
#           ]
#         }
#       },
#       {
#         "_index" : "product-search",
#         "_type" : "_doc",
#         "_id" : "34",
#         "_score" : 5.6917257,
#         "_source" : {
#           "merchandise_id" : "51313308",
#           "search_text" : [
#             "Essentia Water 9.5 pH or Higher Ionized Alkaline Water &#8211; 6pk/1 Liter Bottles",
#             "water",
#             "Supercharged Ionized Alkaline Water",
#             "Ionized for better rehydration*",
#             "1 Liter Recyclable, BPA-free bottles",
#             "Better rehydration* is vital; Essentia is passionate about supplying an overachieving H2O for dynamic doers everywhere, whether exercising, working, studying, dieting, exploring, or practicing",
#             "Essentia Water's pure, smooth alkaline water benefits humans everywhere; by tapping into world-wide water sources, transportation and environmental impact are significantly reduced"
#           ]
#         }
#       }
#     ]
#   }
# }
