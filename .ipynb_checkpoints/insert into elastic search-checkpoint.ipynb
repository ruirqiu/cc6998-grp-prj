# %% [markdown]
# # Read file from json and save only kewords

# %%
import json

#keywords = [  'pen','water', 'coffee', 'ham','tea','bread'
#           'milk','apple', 'cranberry','straberry','banana','blueberry','blackberry','mango','oil','salt',
#          'pepper','sugar','baking sheet','tin roll','foil','syrup','honey','flower','flour','paper','pan','lemon','corn','cucumber','potato','carrot','cauliflower','broccoli', 'beans',
#          'mushroom','rice', 'pasta','lettuce','salary', 'asparagus', 'onion','cabbage','dressing','egg','butter','cheese','juice']
keywords = ['bear', 'beer', 'wine', 'shirt',
    'raspberry', 'strawberry', 'screwdriver', 'wrench', 'soap', 'soup', 'towel', 'pistol', 'bag', 'fork']
id_ = 1042
with open('/Users/yumengluo/Desktop/claire/Columbia/6998/6998-team/cc6998-grp-prj/data/items_summary2.json', 'w') as file:
    for keyword in keywords:

        with open('/Users/yumengluo/Desktop/claire/Columbia/6998/6998-team/cc6998-grp-prj/data/'+keyword+'.json', 'r') as file1:
            merchandise_list = json.load(file1)
            
        for i in range(len(merchandise_list)):
            m = merchandise_list[i]
            ids = { "index" : { "_index": "product-search", "_id" : str(id_) } }
            json.dump(ids, file)
            file.write("\n")
            item = []
            item.append(m['title'])
            item.append(m['keyword'])
            if 'description' in m:
                item += m['description']
            #print(item)
            info = {"merchandise_id": m['id'], "search_text": item}
            json.dump(info, file)
            file.write("\n")
            id_+=1
            
file.close()
f = '/Users/yumengluo/Desktop/claire/Columbia/6998/6998-team/cc6998-grp-prj/data/items_summary2.json'
# !curl -XPOST -u 'claireluo:Abcd1234.' 'https://search-item-search-dqlmodc2m5iid3hfibwvx3egkq.us-east-1.es.amazonaws.com/_bulk' --data-binary @$f -H 'Content-Type: application/json'
# Out:
# {"took":277,"errors":false,"items":[{"index":{"_index":"product-search","_type":"_doc","_id":"1042","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":538,"_primary_term":1,"status":201}},{"index":{"_index":"product-search","_type":"_doc","_id":"1043","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":716,"_primary_term":1,"status":201}},{"index":{"_index":"product-search","_type":"_doc","_id":"1044","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":293,"_primary_term":1,"status":201}},{"index":{"_index":"product-search","_type":"_doc","_id":"1045","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":539,"_primary_term":1,"status":201}},{"index":{"_index":"product-search","_type":"_doc","_id":"1046","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":717,"_primary_term":1,"status":201}},{"index":{"_index":"product-search","_type":"_doc","_id":"1047","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":906,"_primary_term":1,"status":201}},{"index":{"_index":"product-search","_type":"_doc","_id":"1048","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":907,"_primary_term":1,"status":201}},{"index":{"_index":"product-search","_type":"_doc","_id":"1049","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":718,"_primary_term":1,"status":201}},{"index":{"_index":"product-search","_type":"_doc","_id":"1050","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":616,"_primary_term":1,"status":201}},{"index":{"_index":"product-search","_type":"_doc","_id":"1051","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":719,"_primary_term":1,"status":201}},{"index":{"_index":"product-search","_type":"_doc","_id":"1052","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":908,"_primary_term":1,"status":201}},{"index":{"_index":"product-search","_type":"_doc","_id":"1053","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":294,"_primary_term":1,"status":201}},{"index":{"_index":"product-search","_type":"_doc","_id":"1054","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":617,"_primary_term":1,"status":201}},{"index":{"_index":"product-search","_type":"_doc","_id":"1055","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":909,"_primary_term":1,"status":201}},{"index":{"_index":"product-search","_type":"_doc","_id":"1056","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no
#     "total" : {
#       "value" : 24,
#       "relation" : "eq"
#     },
#     "max_score" : 8.38057,
#     "hits" : [
#       {
#         "_index" : "product-search",
#         "_type" : "_doc",
#         "_id" : "1054",
#         "_score" : 8.38057,
#         "_source" : {
#           "merchandise_id" : "53214370",
#           "search_text" : [
#             "Brown Bear Brown Bear by Bill Martin (Board Book)",
#             "bear",
#             "Reading level : 2 - 5 years",
#             "Grade level : Preschool - Kindergarten",
#             "Board book : 28 pages"
#           ]
#         }
#       },
#       {
#         "_index" : "product-search",
#         "_type" : "_doc",
#         "_id" : "1044",
#         "_score" : 8.211611,
#         "_source" : {
#           "merchandise_id" : "82250344",
#           "search_text" : [
#             "Care Bears Cheer Bear 14&#34; Medium Plush Stuffed Animal",
#             "bear",
#             "SOFT HUGGABLE MATERIAL - Cheer Bear is 14 inches in size, comes in a soft huggable material for unlimited bear hugs.",
#             "UNIQUE BELLY BADGE - Cheer Bear wears a belly badge of hope and happiness — a colorful rainbow.",
#             "MEASUARES - 14 Inches (H) x 10 Inches (W) x 5 Inches (D)",
#             "Perfect For Ages 4+"
#           ]
#         }
#       },
#       {
#         "_index" : "product-search",
#         "_type" : "_doc",
#         "_id" : "1045",
#         "_score" : 7.83534,
#         "_source" : {
#           "merchandise_id" : "75546088",
#           "search_text" : [
#             "GUND Philbin Teddy Bear 12-Inch Plush - Chocolate Brown",
#             "bear",
#             "Philbin Teddy Bear 12-Inch Plush",
#             "Chocolate brown plush teddy bear featuring paw pad accents on feet.",
#             "Huggable plush measures 12-inches tall.",
#             "Made from soft, huggable material that meets high-quality GUND standards.",
#             "Surface-washable construction for easy cleaning."
#           ]
#         }
#       },
#       {
#         "_index" : "product-search",
#         "_type" : "_doc",
#         "_id" : "1053",
#         "_score" : 7.526044,
#         "_source" : {
#           "merchandise_id" : "79835912",
#           "search_text" : [
#             "FAO Schwarz Adopt-A-Pets Brown Bear 10&#34; Stuffed Animal",
#             "bear",
#             "10 inch snuggly plush",
#             "Ultra-soft fur",
#             "Attention to detail in design",
#             "Incredibly sturdy construction"
#           ]
#         }
#       },
#       {
#         "_index" : "product-search",
#         "_type" : "_doc",
#         "_id" : "1050",
#         "_score" : 7.273868,
#         "_source" : {
#           "merchandise_id" : "79500015",
#           "search_text" : [
#             "B. toys Teddy Bear, Board Book &#38; Picnic Set - Happyhues Cara Mellow Bear",
#             "bear",
#             "Picnic Play Set: Play with a soft teddy bear, read an educational book, carry play food in the wagon, and set up a picnic with plates and a blanket!",
#             "Includes: This pretend play set comes with a plush bear, board book, 2 plates, 2 cups, grapes, watermelon, corn, a blanket, and a wagon.",
#             "Educational & Developmental: The picnic toys and book improve language skills and help kids learn more about colors, foods, and animals.",
#             "Tiny Hands-Friendly: All of the pieces are easy for tiny hands to hold and play with.",
#             "Age: This play set is recommended for toddlers 18 months +"
#           ]
#         }
#       },
#       {
#         "_index" : "product-search",
#         "_type" : "_doc",
#         "_id" : "1059",
#         "_score" : 7.2279177,
#         "_source" : {
#           "merchandise_id" : "82813111",
#           "search_text" : [
#             "Care Bears Grumpy Bear 14&#34; Medium Plush Stuffed Animal",
#             "bear",
#             "SOFT HUGGABLE MATERIAL - Grumpy Bear is 14 inches in size, comes in a soft huggable material for unlimited bear hugs.",
#             "UNIQUE BELLY BADGE - Grumpy Bear’s belly badge - a rain cloud with falling hearts—is a reminder that even when we’re less than cheery, we are still loved by those closest to us.",
#             "MEASUARES - 14 Inches (H) x 10 Inches (W) x 5 Inches (D)",
#             "Perfect For Ages 4+"
#           ]
#         }
#       },
#       {
#         "_index" : "product-search",
#         "_type" : "_doc",
#         "_id" : "1042",
#         "_score" : 6.988589,
#         "_source" : {
#           "merchandise_id" : "76158420",
#           "search_text" : [
#             "Animal Adventure Jumbo Teddy Bear 21.5&#34; seated Stuffed Animal",
#             "bear",
#             "LUXURIOUS FABRICS & CHARMING DESIGN:  So silky smooth, youll never want to let go!",
#             "HIGH-QUALITY HUG: Superior fabrics and materials deliver a five-star cuddle every time.",
#             "ADORABLE ROOM DÉCOR & PERFECT GIFT: Complete that bedroom theme or give a gift that will be remembered and loved for years to come!",
#             "KIDS 3+ YRS: Plush toy is appropriate and fun for kids 3 years and older.",
#             "HOW TO CLEAN: This stuffed animal is surface washable. Wash away messy play by dampening a soft cloth with water and gently wiping the dirty area until clean."
#           ]
#         }
#       },
#       {
#         "_index" : "product-search",
#         "_type" : "_doc",
#         "_id" : "1060",
#         "_score" : 6.988589,
#         "_source" : {
#           "merchandise_id" : "82637121",
#           "search_text" : [
#             "Care Bears Funshine 14&#34; Medium Stuffed Animal",
#             "bear",
#             "SOFT HUGGABLE MATERIAL - Funshine Bear is 14 inches in size, comes in a soft huggable material for unlimited bear hugs.",
#             "UNIQUE BELLY BADGE - Funshine always looks on the sunny side of life. Happy, perky, and ready to rise with each day, they are equally ready and willing to help others, bear or child alike. It has the perfect belly badge filled with the sunniest smiles lighting up the darkest night or shine a beacon for all to see.",
#             "MEASUARES - 14 Inches (H) x 10 Inches (W) x 5 Inches (D)",
#             "Perfect For Ages 4+"
#           ]
#         }
#       },
#       {
#         "_index" : "product-search",
#         "_type" : "_doc",
#         "_id" : "1065",
#         "_score" : 6.4177957,
#         "_source" : {
#           "merchandise_id" : "53692677",
#           "search_text" : [
#             "GUND DC Comics Superman Brown Teddy Bear Plush - 15&#34; Stuffed Animal",
#             "bear",
#             "15 plush bear",
#             "Styled in classic Superman outfit",
#             "Super soft and durable plush",
#             "Surface washable for easy cleaning"
#           ]
#         }
#       },
#       {
#         "_index" : "product-search",
#         "_type" : "_doc",
#         "_id" : "1055",
#         "_score" : 6.355653,
#         "_source" : {
#           "merchandise_id" : "82250346",
#           "search_text" : [
#             "Care Bears Share Bear 14&#34; Medium Plush Stuffed Animal",
#             "bear",
#             "SOFT HUGGABLE MATERIAL - Share Bear is 14 inches in size, comes in a soft huggable material for unlimited bear hugs.",
#             "UNIQUE BELLY BADGE - Share Bear loves sharing so much that she shows it with her belly badge – two heart-shaped lollipops!",
#             "MEASUARES - 14 Inches (H) x 10 Inches (W) x 5 Inches (D)",
#             "Perfect For Ages 4+"
#           ]
#         }
#       }
#     ]
#   }
# }
